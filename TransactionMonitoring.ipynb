# %%
# %load_ext autoreload
# %autoreload 2

# %%
text = """

17/05/2025 ADEDAYO ADEROJU FOUNDATION|RVSLBP_ETRNBP_17406968|REVERSAL: Transfer of 147000.00 to AMIN AYOBAMI AMZAT (Access Bank)


"""

# %%
import re
match = re.search(r"RVSLBP_[A-Z]+_(\d+)", text)
if match:
    print(match.group(1))
# Out:
# 17406968
